# %%
import itertools
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

class_names = ["cesped_bueno", "otros", "regar_cesped", "replantar_cesped", "sembrar_cesped"]

y_true = []
y_pred = []

for i in range(0, 349):
    y_true.append("cesped_bueno")
    y_pred.append("cesped_bueno")
for i in range(0, 113):
    y_true.append("cesped_bueno")
    y_pred.append("otros")
for i in range(0, 100):
    y_true.append("cesped_bueno")
    y_pred.append("regar_cesped")
for i in range(0, 7):
    y_true.append("cesped_bueno")
    y_pred.append("replantar_cesped")
for i in range(0, 16):
    y_true.append("cesped_bueno")
    y_pred.append("sembrar_cesped")

for i in range(0, 3):
    y_true.append("otros")
    y_pred.append("cesped_bueno")
for i in range(0, 860):
    y_true.append("otros")
    y_pred.append("otros")
for i in range(0, 6):
    y_true.append("otros")
    y_pred.append("regar_cesped")
for i in range(0, 4):
    y_true.append("otros")
    y_pred.append("replantar_cesped")
for i in range(0, 13):
    y_true.append("otros")
    y_pred.append("sembrar_cesped")

for i in range(0, 1):
    y_true.append("regar_cesped")
    y_pred.append("cesped_bueno")
for i in range(0, 174):
    y_true.append("regar_cesped")
    y_pred.append("otros")
for i in range(0, 489):
    y_true.append("regar_cesped")
    y_pred.append("regar_cesped")
for i in range(0, 93):
    y_true.append("regar_cesped")
    y_pred.append("replantar_cesped")
for i in range(0, 30):
    y_true.append("regar_cesped")
    y_pred.append("sembrar_cesped")

for i in range(0, 0):
    y_true.append("replantar_cesped")
    y_pred.append("cesped_bueno")
for i in range(0, 75):
    y_true.append("replantar_cesped")
    y_pred.append("otros")
for i in range(0, 69):
    y_true.append("replantar_cesped")
    y_pred.append("regar_cesped")
for i in range(0, 296):
    y_true.append("replantar_cesped")
    y_pred.append("replantar_cesped")
for i in range(0, 58):
    y_true.append("replantar_cesped")
    y_pred.append("sembrar_cesped")
    
for i in range(0, 0):
    y_true.append("sembrar_cesped")
    y_pred.append("cesped_bueno")
for i in range(0, 176):
    y_true.append("sembrar_cesped")
    y_pred.append("otros")
for i in range(0, 5):
    y_true.append("sembrar_cesped")
    y_pred.append("regar_cesped")
for i in range(0, 9):
    y_true.append("sembrar_cesped")
    y_pred.append("replantar_cesped")
for i in range(0, 281):
    y_true.append("sembrar_cesped")
    y_pred.append("sembrar_cesped")





def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print('Inception_v3, normalizada')
    else:
        print('Inception_v3, sin normalizar')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_true, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes= ["cesped_bueno", "otros", "regar_cesped", "replantar_cesped", "sembrar_cesped"],
                      title='Inception_v3, sin normalizar')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Inception_v3, normalizada')

plt.show()
# Out:
# Inception_v3, sin normalizar
# [[349 113 100   7  16]
#  [  3 860   6   4  13]
#  [  1 174 489  93  30]
#  [  0  75  69 296  58]
#  [  0 176   5   9 281]]
# Inception_v3, normalizada
# [[0.6  0.19 0.17 0.01 0.03]
#  [0.   0.97 0.01 0.   0.01]
#  [0.   0.22 0.62 0.12 0.04]
#  [0.   0.15 0.14 0.59 0.12]
#  [0.   0.37 0.01 0.02 0.6 ]]

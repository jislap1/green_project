# %%
import itertools
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
class_names = ["bicolor_no_madura", "madura", "no_madura", "otros", "podrida"]

y_true = []
y_pred = []

for i in range(0, 278):
    y_true.append("bicolor_no_madura")
    y_pred.append("bicolor_no_madura")
for i in range(0, 19):
    y_true.append("bicolor_no_madura")
    y_pred.append("madura")
for i in range(0, 33):
    y_true.append("bicolor_no_madura")
    y_pred.append("no_madura")
for i in range(0, 8):
    y_true.append("bicolor_no_madura")
    y_pred.append("otros")
for i in range(0, 0):
    y_true.append("bicolor_no_madura")
    y_pred.append("podrida")

for i in range(0, 0):
    y_true.append("madura")
    y_pred.append("bicolor_no_madura")
for i in range(0, 362):
    y_true.append("madura")
    y_pred.append("madura")
for i in range(0, 0):
    y_true.append("madura")
    y_pred.append("no_madura")
for i in range(0, 7):
    y_true.append("madura")
    y_pred.append("otros")
for i in range(0, 49):
    y_true.append("madura")
    y_pred.append("podrida")

for i in range(0, 50):
    y_true.append("no_madura")
    y_pred.append("bicolor_no_madura")
for i in range(0, 0):
    y_true.append("no_madura")
    y_pred.append("madura")
for i in range(0, 291):
    y_true.append("no_madura")
    y_pred.append("no_madura")
for i in range(0, 10):
    y_true.append("no_madura")
    y_pred.append("otros")
for i in range(0, 0):
    y_true.append("no_madura")
    y_pred.append("podrida")

for i in range(0, 0):
    y_true.append("otros")
    y_pred.append("bicolor_no_madura")
for i in range(0, 0):
    y_true.append("otros")
    y_pred.append("madura")
for i in range(0, 9):
    y_true.append("otros")
    y_pred.append("no_madura")
for i in range(0, 553):
    y_true.append("otros")
    y_pred.append("otros")
for i in range(0, 11):
    y_true.append("otros")
    y_pred.append("podrida")
    
for i in range(0, 0):
    y_true.append("podrida")
    y_pred.append("bicolor_no_madura")
for i in range(0, 2):
    y_true.append("podrida")
    y_pred.append("madura")
for i in range(0, 0):
    y_true.append("podrida")
    y_pred.append("no_madura")
for i in range(0, 0):
    y_true.append("podrida")
    y_pred.append("otros")
for i in range(0, 378):
    y_true.append("podrida")
    y_pred.append("podrida")

    
    
    
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print('Inception_ResNet_v2, normalizada')
    else:
        print('Inception_ResNet_v2, sin normalizar')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_true, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes= ["bicolor_no_madura", "madura", "no_madura", "otros", "podrida"],
                      title='Inception_ResNet_v2, sin normalizar')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Inception_ResNet_v2, normalizada')

plt.show()
# Out:
# Inception_ResNet_v2, sin normalizar
# [[278  19  33   8   0]
#  [  0 362   0   7  49]
#  [ 50   0 291  10   0]
#  [  0   0   9 553  11]
#  [  0   2   0   0 378]]
# Inception_ResNet_v2, normalizada
# [[0.82 0.06 0.1  0.02 0.  ]
#  [0.   0.87 0.   0.02 0.12]
#  [0.14 0.   0.83 0.03 0.  ]
#  [0.   0.   0.02 0.97 0.02]
#  [0.   0.01 0.   0.   0.99]]
